# %%
from evaluacion import Evaluacion
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
E = Evaluacion("../Curiocity_Turtle.owl")
E.ShowScore()
# Out:
#               Value  Score
# LCOMOnto   7.053333      2
# WMCOnto2  10.580000      3
# DITOnto   10.000000      1
# NACOnto    1.160000      5
# NOCOnto    2.605263      5
# CBOOnto    1.149425      5
# RFCOnto    7.340909      3
# NOMOnto    6.204545      2
# RROnto     0.153488      1
# PROnto     0.846512      5
# AROnto     0.738636      4
# INROnto    1.125000      5
# ANOnto     1.920455      5
# TMOnto2    1.136364      5

# %%
CRM = Evaluacion("../Erlangen_TURTLE.owl")
CRM.ShowScore()
# Out:
#               Value  Score
# LCOMOnto   6.947826      2
# WMCOnto2  15.980000      1
# DITOnto   10.000000      1
# NACOnto    1.160000      5
# NOCOnto    2.684211      5
# CBOOnto    1.183908      5
# RFCOnto    7.727273      3
# NOMOnto    6.556818      2
# RROnto     0.150221      1
# PROnto     0.849779      5
# AROnto     0.795455      4
# INROnto    1.159091      5
# ANOnto     1.954545      5
# TMOnto2    1.170455      5

# %%
#fig = plt.figure()
#ax = fig.add_axes([0,0,1,1])
#subchar = ['Formal relations', 'Cohesion', 'Tangledness', 'Redundancy', 'Formalization', 'Consistency']
#score = [E.RROnto[1],E.LCOMOnto[1],E.TMOnto2[1],E.ANOnto[1], 5, 5]
#ax.bar(subchar,score)
#plt.show()

# %%
def RadialGraph(subchar:[], score1:[], score2:[], title:str, legend:str, pos=[0.2,0.2]):
    # Initialise the spider plot by setting figure size and polar projection
    plt.figure(figsize=(10, 5))
    plt.subplot(polar=True)    
    theta = np.linspace(0, 2 * np.pi, len(score1))
  
    # Arrange the grid into number of sales equal parts in degrees
    lines, labels = plt.thetagrids(range(0, 360, int(360/len(subchar))), (subchar))
    
    # Plot onto1
    plt.plot(theta, score1)
    plt.fill(theta, score1, 'b', alpha=0.1)
    
    # Plot onto2
    plt.plot(theta, score2)
    #plt.fill(theta, score2, 'b', alpha=0.1)
    
    # Add legend and title for the plot
    leg = plt.legend(labels=(legend), loc=1 , bbox_to_anchor=(pos))
    plt.title(title)
   
    # Display
    plt.show()

# %%
#Summary of Subcharacteristics
#Structural
pd.DataFrame(E.score_struct[:-1], index = E.sub_struct, columns=['Score'])
# Out:
#                   Score
# Formal relations      1
# Cohesion              2
# Tangledness           5
# Redundancy            5
# Formalization         5
# Consistency           5

# %%
pd.DataFrame(CRM.score_struct[:-1], index = CRM.sub_struct, columns=['Score'])
# Out:
#                   Score
# Formal relations      1
# Cohesion              2
# Tangledness           5
# Redundancy            5
# Formalization         5
# Consistency           5

# %%
RadialGraph(E.sub_struct, E.score_struct, CRM.score_struct, legend = ["CURIOCITY","CIDOC CRM"], title = "Structural")

# %%
#Functional adequacy
pd.DataFrame(E.score_fa[:-1], index= E.sub_fa, columns=['Score'])
# Out:
#                                     Score
# Controlled\n vocabulary          5.000000
# Schema &\n value reconciliation  3.750000
# Consistent\n Search & Query      4.000000
# Knowledge\n acquisition          2.666667
# Clustering &\n similiraty        2.500000
# Indexing &\n linking             3.333333
# Results\n representation         2.500000
# Text analysis                    5.000000
# Guidance &\n decision trees      4.500000
# Knowledge\n reuse                4.000000

# %%
pd.DataFrame(CRM.score_fa[:-1], index= CRM.sub_fa, columns=['Score'])
# Out:
#                                     Score
# Controlled\n vocabulary          5.000000
# Schema &\n value reconciliation  3.750000
# Consistent\n Search & Query      4.000000
# Knowledge\n acquisition          2.666667
# Clustering &\n similiraty        2.500000
# Indexing &\n linking             3.333333
# Results\n representation         2.500000
# Text analysis                    5.000000
# Guidance &\n decision trees      4.500000
# Knowledge\n reuse                4.000000

# %%
RadialGraph(E.sub_fa, E.score_fa, CRM.score_fa, legend = ["CURIOCITY","CIDOC CRM"], title = "Functional adequacy", pos = [0.2,0.1])

# %%
#Adaptability, Reliability, Replaceability, Operability
pd.DataFrame(E.score_arro[:-1], index=E.sub_arro, columns=['Score'])
# Out:
#                    Score
# Adaptability    3.000000
# Recoverability  2.000000
# Availability    2.000000
# Replaceability  2.750000
# Learnability    3.333333

# %%
pd.DataFrame(CRM.score_arro[:-1], index=CRM.sub_arro, columns=['Score'])
# Out:
#                 Score
# Adaptability     2.50
# Recoverability   1.50
# Availability     2.00
# Replaceability   2.25
# Learnability     3.00

# %%
RadialGraph(E.sub_arro, E.score_arro, CRM.score_arro, legend = ["CURIOCITY","CIDOC CRM"], title = "Adaptability, Reliability, Replaceability & Operability", pos = [0.25,0.15])

# %%
#Maintainability CURIOCITY
pd.DataFrame(E.score_maintain[:-1], index=E.sub_maintain, columns=['Score'])
# Out:
#                             Score
# Modularity               4.000000
# Reusability              3.166667
# Analysability            2.666667
# Changeability            3.000000
# Modification\nStability  3.600000
# Testability              2.666667

# %%
#Maintainability ERLANGEN CIDOC CRM
pd.DataFrame(CRM.score_maintain[:-1], index=CRM.sub_maintain, columns=['Score'])
# Out:
#                             Score
# Modularity               3.000000
# Reusability              2.833333
# Analysability            2.333333
# Changeability            2.714286
# Modification\nStability  3.200000
# Testability              2.333333

# %%
RadialGraph(E.sub_maintain, E.score_maintain, CRM.score_maintain, legend = ["CURIOCITY","CIDOC CRM"] , title = "Maintainability", pos = [0.2,0.3])

# %%
#Summary of Characteristic
pd.DataFrame(E.score_char[:-1], index=E.sub_char, columns=['Score'])
# Out:
#                          Score
# Structural            3.833333
# Functional\nadequacy  3.725000
# Transferability       3.000000
# Reliability           2.000000
# Compatibility         2.750000
# Maintainability       3.183333

# %%
pd.DataFrame(CRM.score_char[:-1], index=CRM.sub_char, columns=['Score'])
# Out:
#                          Score
# Structural            3.833333
# Functional\nadequacy  3.725000
# Transferability       2.500000
# Reliability           1.750000
# Compatibility         2.250000
# Maintainability       2.735714

# %%
RadialGraph(E.sub_char, E.score_char, CRM.score_char, legend = ["CURIOCITY","CIDOC CRM"] , title = "Characteristics Evaluation", pos = [0.2,0.3])

# %%
metric_char = ['LCOMOnto', 'WMCOnto', 'DITOnto', 'NACOnto', 'NOCOnto', 'CBOOnto', 'RFCOnto', 'NOMOnto', 'RROnto', 'INROnto', 'TMOnto']
cit_score = [2, 3, 1, 5, 5, 5, 3, 2, 1, 5, 5] #repeat first
erl_score = [2, 1, 1, 5, 5, 5, 3, 2, 1, 5, 5]
df = pd.DataFrame({'value1':cit_score , 'value2':erl_score })
 
# Reorder it following the values of the first value:
#ordered_df = df.sort_values(by='value1')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
plt.hlines(y=my_range, xmin=df['value1'], xmax=df['value2'], color='grey', alpha=0.4)
plt.scatter(df['value1'], my_range, color='red', alpha=1, label='CURIOCITY', s=80)
plt.scatter(df['value2'], my_range, color='blue', alpha=0.4 , label='ERLANGEN-CRM', s=80, marker='s')
plt.legend(loc=8, bbox_to_anchor=[0.5,-0.35])
plt.rcParams['grid.alpha'] = .1
plt.grid() 
# Add title and axis names
plt.yticks(my_range, metric_char)#, df['group'])
plt.title("Structural Level Evaluation", loc='center')
plt.xlabel('OquaRE Score')
plt.ylabel('Metrics')

# Show the graph
plt.show()
